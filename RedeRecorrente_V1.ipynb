# %%
import os
import subprocess

def download(url, path):

    # comando para fazer o download
    cmd = ['wget', '-q', url, '-O', '%s' %(path)]

    # executa o comando sem exibir a saída na tela
    processo = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # aguarda o término do download
    stdout, stderr = processo.communicate()

    # Verifica se o processo foi concluído com sucesso (código de retorno zero)
    if processo.returncode == 0:
        print(f'Processo finalizado.')
    else:
        print(f'Houve um erro: {stderr.decode("utf-8")}')

# especifica o local onde ficarao os arquivos
pathFiles = 'dados/'

# cria uma pasta onde ficarao os arquivos
if not os.path.isdir(pathFiles):
    os.mkdir(pathFiles)

url = 'https://www.nuscenes.org/data/v1.0-mini.tgz'
pathDataset1 = pathFiles + '/nuscenes_v1.0-mini.tgz'
download(url, pathDataset1)
# Out:
# Processo finalizado.

# %%
import tarfile

def descompacta(path, pathFolder):

    try:
        # Descompacta ao arquivo
        with tarfile.open(pathDataset1, 'r:gz') as tar:
          tar.extractall(path=pathFolder)

        print("Arquivo descompactado com sucesso!")
    except:
        print("Houve um erro ao tentar descompactar o arquivo")

pathFiles = pathFiles + "/nuscenes"

# Cria o diretório de extração se não existir
os.makedirs(pathFiles, exist_ok=True)

descompacta(pathDataset1, pathFiles)
# Out:
# Arquivo descompactado com sucesso!

# %%
# !pip install nuscenes-devkit &> /dev/null  # Install nuScenes.

# %% [markdown]
# # Converte uma bounding box 3D para 2D
#
# A função abaixo recebe as informações da bounding box 3D de um determinado objeto e as informações de calibração da câmera. Com base nisso, ela faz a conversão para 2D. Esse código foi baseado no notebook disponível nesse link:
# - <https://github.com/asvath/mobile_robotics/blob/master/nuscenes%20extract%20and%20write%20out%202d%20annotation%20boxes-revised%20to%20truncate%20bb.ipynb>

# %%
import numpy as np
import pandas as pd
import cv2
from nuscenes.nuscenes import NuScenes

from pyquaternion import Quaternion

from nuscenes.utils.data_classes import Box
from nuscenes.utils.geometry_utils import view_points, BoxVisibility, box_in_image

import matplotlib.pyplot as plt

def threeD_2_twoD(boxsy,intrinsic): #input is a single annotation box
    '''
    given annotation boxes and intrinsic camera matrix
    outputs the 2d bounding box coordinates as a list (all annotations for a particular sample image)
    '''
    corners = boxsy.corners()
    x = corners[0,:]
    y = corners[1,:]
    z = corners[2,:]
    x_y_z = np.array((x,y,z))
    orthographic = np.dot(intrinsic,x_y_z)
    perspective_x = orthographic[0]/orthographic[2]
    perspective_y = orthographic[1]/orthographic[2]
    perspective_z = orthographic[2]/orthographic[2]

    min_x = int(np.min(perspective_x))
    max_x = int(np.max(perspective_x))
    min_y = int(np.min(perspective_y))
    max_y = int(np.max(perspective_y))

    return min_x,max_x,min_y,max_y

def getBoundBox(nusc, sample, camera, annotation_metadata):
    """
    Obtém a bounding box 3D e, depois, usando as informações da câmera,
    chama a função que converte para 2D
    """

    camera_token = sample['data'][camera]

    # Carregue os dados da câmera
    cam_data = nusc.get('sample_data', camera_token)

    cam_intrinsics = np.array(nusc.get('calibrated_sensor', cam_data['calibrated_sensor_token'])['camera_intrinsic'])
    cam_height = cam_data['height']
    cam_width = cam_data['width']

    # obtenha a bounding box 3D do pedestre
    # a variavel ann foi filtrada a partir do token do pedestre. Portanto, o parametro translation contem
    # as coordenadas do pedestre em questao
    translation = annotation_metadata['translation']
    size = annotation_metadata['size']
    rotation = Quaternion(annotation_metadata['rotation'])
    bbox = Box(translation, size, rotation)

    # Obtenha a pose da câmera
    ego_pose = nusc.get('ego_pose', cam_data['ego_pose_token'])
    cam_pose = nusc.get('calibrated_sensor', cam_data['calibrated_sensor_token'])

    # Transforme a bounding box do pedestre para o sistema de coordenadas da câmera
    bbox.translate(-np.array(ego_pose['translation']))
    bbox.rotate(Quaternion(ego_pose['rotation']).inverse)
    bbox.translate(-np.array(cam_pose['translation']))
    bbox.rotate(Quaternion(cam_pose['rotation']).inverse)

    # Verificar se a bounding box está dentro do campo de visão da câmera
    if not box_in_image(bbox, cam_intrinsics, imsize=[cam_width, cam_height], vis_level=BoxVisibility.ANY):
        return None, None, None, None

    # converts box into image plane
    min_x, max_x, min_y, max_y = threeD_2_twoD(bbox,cam_intrinsics)

    return min_x, max_x, min_y, max_y

# %% [markdown]
# A função abaixo aplica a conversão das bounding box para todas as anotações da base de dados. Além disso, guarda todas as informações em um dataframe.

# %%
def get_scenes(nusc):

    columns = ['scene_token', 'category_name', 'instance_token', 'translation', 'size', 'rotation']
    annotations_df = pd.DataFrame(columns=columns)

    dataList = []
    for scene in nusc.scene:
        scene_token = scene['token']
        print(f"Processing scene: {scene_token}")  # Adicione esta linha para depuração
        sample_token = scene['first_sample_token']

        while sample_token:
            sample = nusc.get('sample', sample_token)

            scene_token = sample['scene_token']
            timestamp = sample['timestamp']

            # coletar todos os caminhos das imagens da câmera
            for sensor_channel in ['CAM_FRONT', 'CAM_BACK', 'CAM_FRONT_LEFT', 'CAM_FRONT_RIGHT', 'CAM_BACK_LEFT', 'CAM_BACK_RIGHT']:
                sample_data_token_camera = sample['data'][sensor_channel]
                sample_data_camera = nusc.get('sample_data', sample_data_token_camera)
                image_path = sample_data_camera['filename']


                for annotation_token in sample['anns']:
                    annotation_metadata = nusc.get('sample_annotation', annotation_token)
                    instance_metadata = nusc.get('instance', annotation_metadata['instance_token'])
                    category_metadata = nusc.get('category', instance_metadata['category_token'])

                    # visibility_token = annotation_metadata['visibility_token']

                    # obter descrição da visibilidade
                    # visibility = nusc.get('visibility', visibility_token)['description']

                    min_x, max_x, min_y, max_y = getBoundBox(nusc, sample, sensor_channel, annotation_metadata)

                    data = {
                        'sample_token_camera': sample_data_token_camera,
                        'sample_token': sample_token,
                        'scene_token': scene_token,  # Certifique-se de que `scene_token` está sendo atribuído aqui
                        'instance_token': annotation_metadata['instance_token'],
                        'category_name': category_metadata['name'],
                        'image_path': image_path,
                        'camera': sensor_channel,
                        'translation': annotation_metadata['translation'],
                        'size': annotation_metadata['size'],
                        'rotation': annotation_metadata['rotation'],
                        'timestamp': timestamp,
                        # 'box_visibility': visibility_token,
                        'bbox_min_x': min_x,
                        'bbox_max_x': max_x,
                        'bbox_min_y': min_y,
                        'bbox_max_y': max_y,
                    }

                    dataList.append(data)

            sample_token = sample['next']

    # converta para um dataframe
    annotations_df = pd.DataFrame(dataList)

    # Ordenar pelo campo 'timestamp'
    annotations_df = annotations_df.sort_values(by='timestamp')

    annotations_df.to_csv('annotations_with_scenes.csv', index=False)

    return annotations_df

# %% [markdown]
# Converte toda a base de dados e salva como .csv

# %%
if __name__ == "__main__":

    pathDataset = "/content/dados/nuscenes/"

    path = "dados/annotations_bbox2D.csv"

    nusc = NuScenes(version='v1.0-mini', dataroot=pathDataset, verbose=True)

    annotations_df = get_scenes(nusc)

    annotations_df.to_csv(path, index=False)
# Out:
# ======
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.598 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ======
# Processing scene: cc8c0bf57f984915a77078b10eb33198
# Processing scene: fcbccedd61424f1b85dcbf8f897f9754
# Processing scene: 6f83169d067343658251f72e1dd17dbc
# Processing scene: bebf5f5b2a674631ab5c88fd1aa9e87a
# Processing scene: 2fc3753772e241f2ab2cd16a784cc680
# Processing scene: c5224b9b454b4ded9b5d2d2634bbda8a
# Processing scene: 325cef682f064c55a255f2625c533b75
# Processing scene: d25718445d89453381c659b9c8734939
# Processing scene: de7d80a1f5fb4c3e82ce8a4f213b450a
# Processing scene: e233467e827140efa4b42d2b4c435855

# %% [markdown]
# # Filtra a base de dados
#
# A função abaixo filtra apenas algumas categorias de interesse.

# %%
def filtraCategorias(annotations_df):
    # Definir as categorias de interesse - apenas pedestres
    categories_of_interest = [
        'human.pedestrian.adult',
        'human.pedestrian.child',
        'human.pedestrian.construction_worker',
        'human.pedestrian.personal_mobility',
        'human.pedestrian.police_officer'
    ]

    # Filtrar as anotações que correspondem a essas categorias
    filtered_annotations_df = annotations_df[annotations_df['category_name'].isin(categories_of_interest)]

    return filtered_annotations_df

# %% [markdown]
# A função abaixo remove as bounding box nulas. Depois, aplica as duas funções.

# %%
def remove_bbox_nula(df):
    """
    Remove as linhas onde a bounding box é nula
    """

    df = df.dropna(subset=['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y'])

    return df

# %% [markdown]
# Aplica a função que seleciona algumas categorias e a função que remove as bounding box nulas.

# %%
if __name__ == "__main__":

  path_filtered = "dados/annotations_bbox2D_filtered.csv"

  # aplica a função que filtra as categorias desejadas
  annotations_df_filtered = filtraCategorias(annotations_df)

  # aplica a função que remove as bouding box nulas
  annotations_df_filtered = remove_bbox_nula(annotations_df_filtered)

  # salva o dataframe
  annotations_df_filtered.to_csv(path_filtered, index=False)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, MaxPooling2D, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import random
import os

# Função para definir a seed global para reprodução dos resultados
def set_seed(seed_value=42):
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)

    # Configurações adicionais para reprodução consistente no TensorFlow
    os.environ['PYTHONHASHSEED'] = str(seed_value)  # Hash seed
    os.environ['TF_DETERMINISTIC_OPS'] = '1'  # Força operações determinísticas no TensorFlow

    # Configurações adicionais para TensorFlow
    # Definir configuração para limitar o uso de threads paralelos
    tf.config.threading.set_intra_op_parallelism_threads(1)
    tf.config.threading.set_inter_op_parallelism_threads(1)

# Chamar a função para definir a seed
set_seed()

# %%
# Função para calcular o IoU
def calcula_iou(bbox_real, bbox_predito):
    xA = max(bbox_real[0], bbox_predito[0])
    yA = max(bbox_real[2], bbox_predito[2])
    xB = min(bbox_real[1], bbox_predito[1])
    yB = min(bbox_real[3], bbox_predito[3])

    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    boxA_area = (bbox_real[1] - bbox_real[0] + 1) * (bbox_real[3] - bbox_real[2] + 1)
    boxB_area = (bbox_predito[1] - bbox_predito[0] + 1) * (bbox_predito[3] - bbox_predito[2] + 1)

    iou = interArea / float(boxA_area + boxB_area - interArea)
    return iou

def calcula_iou_medio(y_true, y_pred):
    iou_sum = 0
    count = len(y_true)

    for i in range(count):
        iou_sum += calcula_iou(y_true[i], y_pred[i])

    return iou_sum / count

# %%
# Carregar o DataFrame gerado com as anotações das bounding boxes
annotations_df = pd.read_csv('/content/dados/annotations_bbox2D_filtered.csv')

# Ordenar pelo 'instance_token' e 'timestamp' para garantir que os dados estejam na ordem correta
annotations_df = annotations_df.sort_values(by=['instance_token', 'timestamp'])

# Shift para obter o bbox do timestamp anterior e criar colunas de diferença
annotations_df['prev_bbox_min_x'] = annotations_df.groupby('instance_token')['bbox_min_x'].shift(1)
annotations_df['prev_bbox_max_x'] = annotations_df.groupby('instance_token')['bbox_max_x'].shift(1)
annotations_df['prev_bbox_min_y'] = annotations_df.groupby('instance_token')['bbox_min_y'].shift(1)
annotations_df['prev_bbox_max_y'] = annotations_df.groupby('instance_token')['bbox_max_y'].shift(1)

# Remove as linhas onde não temos dados prévios
annotations_df = annotations_df.dropna(subset=['prev_bbox_min_x', 'prev_bbox_max_x', 'prev_bbox_min_y', 'prev_bbox_max_y'])

# Definir as features (inputs) e a variável alvo (outputs)
X = annotations_df[['prev_bbox_min_x', 'prev_bbox_max_x', 'prev_bbox_min_y', 'prev_bbox_max_y',
                    'bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]
y = annotations_df[['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]

# Converter para numpy arrays e ajustar a dimensão para o modelo RNN
X = X.values.reshape((X.shape[0], 1, X.shape[1]))
y = y.values

# %%
# Dividir em treino e teste mantendo a ordem temporal
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Função que cria o modelo RNN
def create_rnn_model(input_shape, hidden_units, activation, learning_rate):
    # Definir o input da rede
    input_layer = Input(shape=input_shape)

    # Adicionar camadas LSTM
    x = input_layer
    for units in hidden_units:
        x = LSTM(units=units, activation=activation, return_sequences=True)(x)

    # Adicionar a última camada LSTM sem "return_sequences"
    x = LSTM(units=hidden_units[-1], activation=activation)(x)

    # Camada densa final
    output_layer = Dense(4, activation='linear')(x)

    # Criar o modelo
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Função para testar os modelos com diferentes hiperparâmetros
def test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list):
    best_iou = 0
    best_params = None

    for hidden_units in hidden_units_list:
        for activation in activations:
            for learning_rate in learning_rates:
                for epochs in epochs_list:
                    print(f"Testing model with hidden_units={hidden_units}, activation={activation}, learning_rate={learning_rate}, epochs={epochs}")

                    # Criar o modelo
                    model = create_rnn_model(X_train.shape[1:], hidden_units, activation, learning_rate)

                    # Treinar o modelo
                    model.fit(X_train, y_train, epochs=epochs, batch_size=32, verbose=0)

                    # Fazer previsões
                    y_pred = model.predict(X_test)

                    # Calcular o IoU médio
                    iou_medio = calcula_iou_medio(y_test, y_pred)
                    print(f"IoU médio: {iou_medio}")

                    # Atualizar os melhores parâmetros se necessário
                    if iou_medio > best_iou:
                        best_iou = iou_medio
                        best_params = (hidden_units, activation, learning_rate, epochs)

    print(f"Melhor IoU: {best_iou}")
    print(f"Melhores parâmetros: hidden_units={best_params[0]}, activation={best_params[1]}, learning_rate={best_params[2]}, epochs={best_params[3]}")

# Execução do código no ambiente Colab
set_seed()

# Definir os hiperparâmetros a serem testados
hidden_units_list = [
    (128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]  # Diferentes tamanhos de camadas ocultas
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]  # Diferentes taxas de aprendizado
epochs_list = [10, 20, 30, 40, 50]  # Diferentes números de épocas a serem testados

# Testar os modelos
test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list)
# Out:
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.03241936945436609
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.055836415512628336
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.08151512334369597
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.14631403312470484
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.08042616252170141
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1486628654485841
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.34003606770486233
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2941820076609814
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3668326788074966
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.43194548271024114
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.7319195301391327
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06681726764596575
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06812031289553398
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.01313178692284197
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.007568019645313776
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07012912689798885
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.061046991669580476
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.14835776301186784
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2369064851897155
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06669665745782907
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06591760268802745
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0666157886907226
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3768148484561549
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.0677293228362256
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06546566990293291
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.2933837557917001
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.12133146109579662
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1838804127622133
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.050448389367687085
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.054712617217681093
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.045768631568723406
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.13986536588399337
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1843157022891094
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.28690182292082034
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06642988787036273
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.36358138506529164
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.35233318252138157
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05849061265930898
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.32560778011317765
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07128874254890664
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3353213379522726
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.38119202076943437
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.01757068768376679
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06335764710754585
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.10223999156908498
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0719078067153023
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0639907858889871
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.34887782553276114
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0679948940965303
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.3864048057802127
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3863779873274555
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07975862219193339
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.245309339744021
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.014539436862364929
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.13406812787441938
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0714044300517308
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.04694874174080921
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05318214727228161
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.02994066189428951
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.061192048457696865
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06561978248152994
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.29331555007751997
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.06524737286493687
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.35024961667012044
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06764577292422547
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.31573018558658683
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3040542545311956
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07386933345610579
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06941661053017331
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.007426197086148908
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.08145914262176687
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.038457939769850985
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.011088313142617658
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06295928467154306
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06111219483011332
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.06671114553698945
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06626857551005298
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.36290947177360033
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.06769973455299509
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.307507889478977
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06923939989774253
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.051257076790042766
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1189987487755437
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 3ms/step
# IoU médio: 0.33547486222557465
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0006420302253581115
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.03180419597135872
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.11172546449353574
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07044405814415146
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.11019717632726923
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.21403970495146368
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2916591770068615
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3593769550277001
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.6836520329434206
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.37297021800277225
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06805942764403582
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.31688885122560195
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.6296612994289209
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.37008808445540087
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.03788763644954219
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05564243230923219
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.013311925921701101
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05305230265354435
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.09829172728182711
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.21172482577924603
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.33594464687471026
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06566359357167052
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0668273211994846
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06776762987825691
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.35840809163465687
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.32991897082730715
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2940676621920209
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.248235102076544
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07333635319035878
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.008549509262945787
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05311806393087771
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.08133743623299665
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06078472322546747
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.029711729615621654
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2909097677860401
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2314824467428472
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3438360392041715
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.38863861084635115
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.34685674247936304
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.19081929922649546
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3791297523139763
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.37194520110892115
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3809298066329094
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.03809184668718941
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05395362243542996
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1435680806769803
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1812716426139465
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.34532977393487657
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2833653910977358
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2862791766570542
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07160778457532797
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.32805582485485146
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.10113499807120192
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.26783483613129605
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.21156928514988144
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3754962015930938
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0012280464370174175
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06013905022490589
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0702396472023016
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0638803998987119
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07827665372926351
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3105625675677666
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3592309081832518
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3683519280394287
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.35303379681663477
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3308290373105488
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2930352242148164
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07651720393517206
# Testing model with hidden_units=(64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2627866070222464
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.03916183618412841
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.10020697350396494
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.19597749215354415
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06318534554779742
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.22585688027776638
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2295735161776159
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.30657526479913344
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06635773152900461
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.36692480166845143
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06752359245432439
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.31459569677734706
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07181001733627185
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.060414060308421856
# Testing model with hidden_units=(64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07341177705487477
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.017273115958107974
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.020298097396076117
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.08475431431985496
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05128252051222417
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1075561161349292
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.12225381164771607
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.27659145073053587
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.34070948398591877
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.39058316432615287
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.5009053035675702
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.34041848181559053
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.327240390701151
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.6892471961429751
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2823562809375071
# Testing model with hidden_units=(32, 16, 8), activation=linear, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3822077720131839
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.038553399145710064
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.05023851874085347
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.045209574458519676
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.03452016750152878
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.050820043482521594
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.26584044940657064
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3537931405486191
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3606737022729922
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.36351888733931087
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06880059356675279
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.33939129667332124
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07082784360773632
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07505925483689625
# Testing model with hidden_units=(32, 16, 8), activation=relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07607047092809359
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.010380260560277077
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06131913630233786
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.1465278762286694
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07970904350071593
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07889550842160382
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.20254810255204378
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.362143273536708
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2644530625521292
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2849141987490983
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06916124698354847
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3294927603018174
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.7488309395828915
# Testing model with hidden_units=(32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.38720046669630626
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.013530333551731047
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.02868682255005128
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.045391889539163316
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.056502585859113094
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.061137493706682235
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06666845884251935
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.34504427903644713
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0741770834067537
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07016056956507817
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.07129963955005492
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2687545506297845
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.01530506142727578
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.014956774917088425
# Testing model with hidden_units=(32, 16, 8), activation=selu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.12271702219973482
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0432282360636303
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.03163468014614244
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06448803961168041
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.19716754873038467
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.29338801760419614
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.334986876162884
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06659211821676637
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.36752429164857053
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.35310884794993724
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.2909250804213886
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06973822128385189
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.26512971299043037
# Testing model with hidden_units=(32, 16, 8), activation=swish, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3833297469881243
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.0357181590229899
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.040781772606211686
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.04803398560262575
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.04327023974813421
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.06402850270421402
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.17685019917813996
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3377184909411575
# Testing model with hidden_units=(32, 16, 8), activation=mish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.3578664710395426
# ...
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.5323486471679318
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.08889516021639941
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.08781604536917496
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.21800294868389677
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.2591690641408695
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3327354868363149
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3066707788877221
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6371599219220425
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6374214427590352
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7273605277187429
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7892601852123525
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7021599675362277
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.5260086079060151
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.8326646521680612
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.770147940385396
# Testing model with hidden_units=(32, 32), activation=linear, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7895527788702067
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.07258589053191107
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.093068423474018
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.24153686025561344
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.18324581067138537
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.2650556828111863
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.362545803397339
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3310846888544938
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.5841621812301696
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6087015842095987
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7693019528860486
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.5958225501517106
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.5960754884813734
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6306288638157295
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.31599754741232616
# Testing model with hidden_units=(32, 32), activation=relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7129255555285199
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.05558176263448241
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.1510551803638278
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.23193863820654376
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.1565593935163822
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.22811522970480053
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.14350163596435966
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3445760569549144
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.44747046456816003
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6618256459131662
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6831795394373208
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3607962632781784
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6681207818631583
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7404462849598318
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.8130679704107133
# Testing model with hidden_units=(32, 32), activation=leaky_relu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7490282573416306
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.07759349588880228
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.16460025825591557
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.08916154843394018
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.2760845848376917
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.24652385373740515
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.22516815990572267
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.31796512095218316
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.4882042099626088
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6325114544516846
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7745887118203536
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.575867422680535
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.5226443816658601
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.4577737498059659
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6300415280752908
# Testing model with hidden_units=(32, 32), activation=selu, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6630135985775708
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.047680869077113816
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.09441774706766067
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.23105037798609523
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.24056508070504484
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.24897611266451106
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3228619180484279
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3007791541987376
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.35359861740661097
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6987789808936475
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7743861454485081
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.632877980078445
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6855328807511817
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 1s 2ms/step
# IoU médio: 0.677554769956129
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7199204756911999
# Testing model with hidden_units=(32, 32), activation=swish, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6861926993573847
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.0001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.11140767323492
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.0001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.09553046063780023
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.0001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.2473118430906445
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.0001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.2225347717425825
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.0001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.22591806533767847
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.001, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.2338472303281448
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.001, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.3109111724078132
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.001, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.5583272253960075
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.001, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6586325092432147
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.001, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.8111122675447572
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.01, epochs=10
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6614507486310129
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.01, epochs=20
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.5327466945050207
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.01, epochs=30
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.7982768855335022
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.01, epochs=40
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6865389201038911
# Testing model with hidden_units=(32, 32), activation=mish, learning_rate=0.01, epochs=50
# 35/35 [==============================] - 0s 2ms/step
# IoU médio: 0.6945694560945352
# Melhor IoU: 0.8326646521680612
# Melhores parâmetros: hidden_units=(32, 32), activation=linear, learning_rate=0.01, epochs=30

# %%
from tensorflow.keras.layers import GRU

# %%
# Dividir em treino e teste mantendo a ordem temporal
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Função que cria o modelo RNN (agora utilizando GRU)
def create_rnn_model(input_shape, hidden_units, activation, learning_rate):
    # Definir o input da rede
    input_layer = Input(shape=input_shape)

    # Adicionar camadas GRU
    x = input_layer
    for units in hidden_units:
        x = GRU(units=units, activation=activation, return_sequences=True)(x)

    # Adicionar a última camada GRU sem "return_sequences"
    x = GRU(units=hidden_units[-1], activation=activation)(x)

    # Camada densa final
    output_layer = Dense(4, activation='linear')(x)

    # Criar o modelo
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Função para testar os modelos com diferentes hiperparâmetros
def test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list):
    best_iou = 0
    best_params = None

    for hidden_units in hidden_units_list:
        for activation in activations:
            for learning_rate in learning_rates:
                for epochs in epochs_list:
                    print(f"Testing model with hidden_units={hidden_units}, activation={activation}, learning_rate={learning_rate}, epochs={epochs}")

                    # Criar o modelo
                    model = create_rnn_model(X_train.shape[1:], hidden_units, activation, learning_rate)

                    # Treinar o modelo
                    model.fit(X_train, y_train, epochs=epochs, batch_size=32, verbose=0)

                    # Fazer previsões
                    y_pred = model.predict(X_test)

                    # Calcular o IoU médio
                    iou_medio = calcula_iou_medio(y_test, y_pred)
                    print(f"IoU médio: {iou_medio}")

                    # Atualizar os melhores parâmetros se necessário
                    if iou_medio > best_iou:
                        best_iou = iou_medio
                        best_params = (hidden_units, activation, learning_rate, epochs)

    print(f"Melhor IoU: {best_iou}")
    print(f"Melhores parâmetros: hidden_units={best_params[0]}, activation={best_params[1]}, learning_rate={best_params[2]}, epochs={best_params[3]}")

# Execução do código no ambiente Colab
set_seed()

# Definir os hiperparâmetros a serem testados
hidden_units_list = [
    (128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]  # Diferentes tamanhos de camadas ocultas
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]  # Diferentes taxas de aprendizado
epochs_list = [10, 20, 30, 40, 50]  # Diferentes números de épocas a serem testados

# Testar os modelos
test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list)
# Out:
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0027979637841374703
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.005795452782118578
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.008729198715110516
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.017487609553004442
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016465474590666225
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.007857579452866744
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.011298004973275228
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.013448735320934452
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.011619088764622431
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016024722752770185
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0005378213298577268
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0010401391962595481
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0008134090379391885
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0009055894852671122
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.000939433873997612
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.004672199941054358
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.007719660520001067
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016150377569801415
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01590262017000419
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01389711634947645
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.015995843542227658
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01335108556592953
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.012839008793787564
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.02247563303888005
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01749425598932212
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0071563380823084465
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.006435622394579953
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.013431501020117562
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.017163914601396588
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.022396175730633787
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0008721922369270081
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.010426503943575525
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 5ms/step
# IoU médio: 0.0074135254130390455
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.014390905488990809
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.008096648961810017
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.005933849416370108
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.014045267096897563
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.012248067684522714
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.015955997715312583
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016486050402030442
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0002779777429456331
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.005889898143783934
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.013223696212868723
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.00715776952173684
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0014169410242511258
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.014059702226032967
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016601180086751804
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.014293466524212239
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.012570858983417846
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.022665387070544385
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.020065859578573732
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.009048268731479509
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.012310209929769632
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.04196346910223249
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01697740814538791
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.015820099360445684
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01374188375474703
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.012337284354425233
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.014067891728321518
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016011053025225305
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.004090462309820056
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.012598417454266684
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016435569936561364
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.010973925720189077
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.019124870783182254
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.018771052207053194
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01166388125988721
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.021213898698679335
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01969339264258537
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.005950169022148082
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.015564240383878467
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.015650727862141597
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=swish, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0024827605869749666
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.007553214766379947
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01522920597055003
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.018129528223921828
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 5ms/step
# IoU médio: 0.015129983740689957
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.016115908566537752
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 5ms/step
# IoU médio: 0.018337879948455895
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.013587985238989414
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.021542996264324283
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.019690829656452326
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01454973521836653
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.010521647241109397
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.015575287365931372
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(128, 64, 32, 16, 8), activation=mish, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.01957945209876541
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.00044552048720722484
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0010269078727172588
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.007541772799673297
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.012575578963115728
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.006878100791557511
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0149423458132622
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.018619062196639856
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.01426208579853547
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.01322524257461085
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.020151820499350236
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.005069339639389244
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0046400810719397214
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.003038166355523815
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.001960134181397486
# Testing model with hidden_units=(64, 32, 16, 8), activation=linear, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.007335942123115657
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.019028925017178067
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.010482355496001178
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.016656425160818465
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.02095255093332393
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.005750711029943904
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.01480738701094693
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.015505342176691535
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.007716809118187966
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.011949994101278115
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.007891894734337586
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.01574055618275478
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.006840930248160757
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.023222821392195264
# Testing model with hidden_units=(64, 32, 16, 8), activation=relu, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.01608549344959725
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.017363471342045023
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.013755768256931455
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0159054712741371
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.013655158684171019
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.016006245711008178
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.013245785696583742
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.021569177287061245
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.015526746998916237
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.020505201783474244
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.015785353061244102
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.004256458791881922
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.020895908124928437
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.012121958270589315
# Testing model with hidden_units=(64, 32, 16, 8), activation=leaky_relu, learning_rate=0.01, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.00027654122081229184
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=30
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.010561833692249837
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.013695430548464742
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.0001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.021866680567983517
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.016781762376056726
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.011971765415893825
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=30
# 29/29 [==============================] - 1s 4ms/step
# IoU médio: 0.009145589710709638
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=40
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.015884490568943383
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.001, epochs=50
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.013532694635840082
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=10
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0019839074565925112
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=20
# 29/29 [==============================] - 1s 3ms/step
# IoU médio: 0.0
# Testing model with hidden_units=(64, 32, 16, 8), activation=selu, learning_rate=0.01, epochs=30

# %%
# Função para calcular o IoU
def calcula_iou(bbox_real, bbox_predito):
    xA = max(bbox_real[0], bbox_predito[0])
    yA = max(bbox_real[2], bbox_predito[2])
    xB = min(bbox_real[1], bbox_predito[1])
    yB = min(bbox_real[3], bbox_predito[3])

    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    boxA_area = (bbox_real[1] - bbox_real[0] + 1) * (bbox_real[3] - bbox_real[2] + 1)
    boxB_area = (bbox_predito[1] - bbox_predito[0] + 1) * (bbox_predito[3] - bbox_predito[2] + 1)

    iou = interArea / float(boxA_area + boxB_area - interArea)
    return iou

def calcula_iou_medio(y_true, y_pred):
    iou_sum = 0
    count = len(y_true)

    for i in range(count):
        iou_sum += calcula_iou(y_true[i], y_pred[i])

    return iou_sum / count

# Carregar o DataFrame gerado com as anotações das bounding boxes
annotations_df = pd.read_csv('/content/dados/annotations_bbox2D_filtered.csv')

# Ordenar pelo 'instance_token' e 'timestamp' para garantir que os dados estejam na ordem correta
annotations_df = annotations_df.sort_values(by=['instance_token', 'timestamp'])

# Shift para obter múltiplos bboxes anteriores e criar colunas de diferença
time_steps = 5  # Número de timestamps anteriores a serem usados como input
for i in range(1, time_steps + 1):
    annotations_df[f'prev_bbox_min_x_{i}'] = annotations_df.groupby('instance_token')['bbox_min_x'].shift(i)
    annotations_df[f'prev_bbox_max_x_{i}'] = annotations_df.groupby('instance_token')['bbox_max_x'].shift(i)
    annotations_df[f'prev_bbox_min_y_{i}'] = annotations_df.groupby('instance_token')['bbox_min_y'].shift(i)
    annotations_df[f'prev_bbox_max_y_{i}'] = annotations_df.groupby('instance_token')['bbox_max_y'].shift(i)

# Remove as linhas onde não temos dados suficientes dos timestamps anteriores
annotations_df = annotations_df.dropna(subset=[f'prev_bbox_min_x_{i}' for i in range(1, time_steps + 1)])

# Definir as features (inputs) e a variável alvo (outputs)
input_columns = [
    f'prev_bbox_min_x_{i}' for i in range(1, time_steps + 1)
] + [
    f'prev_bbox_max_x_{i}' for i in range(1, time_steps + 1)
] + [
    f'prev_bbox_min_y_{i}' for i in range(1, time_steps + 1)
] + [
    f'prev_bbox_max_y_{i}' for i in range(1, time_steps + 1)
]

X = annotations_df[input_columns]
y = annotations_df[['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]

# Converter para numpy arrays e ajustar a dimensão para o modelo RNN
X = X.values.reshape((X.shape[0], time_steps, 4))
y = y.values

# Dividir em treino e teste mantendo a ordem temporal
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Função que cria o modelo RNN (agora utilizando GRU)
def create_rnn_model(input_shape, hidden_units, activation, learning_rate):
    # Definir o input da rede
    input_layer = Input(shape=input_shape)

    # Adicionar camadas GRU
    x = input_layer
    for units in hidden_units:
        x = GRU(units=units, activation=activation, return_sequences=True)(x)

    # Adicionar a última camada GRU sem "return_sequences"
    x = GRU(units=hidden_units[-1], activation=activation)(x)

    # Camada densa final
    output_layer = Dense(4, activation='linear')(x)

    # Criar o modelo
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Função para testar os modelos com diferentes hiperparâmetros
def test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list):
    best_iou = 0
    best_params = None

    for hidden_units in hidden_units_list:
        for activation in activations:
            for learning_rate in learning_rates:
                for epochs in epochs_list:
                    print(f"Testing model with hidden_units={hidden_units}, activation={activation}, learning_rate={learning_rate}, epochs={epochs}")

                    # Criar o modelo
                    model = create_rnn_model(X_train.shape[1:], hidden_units, activation, learning_rate)

                    # Treinar o modelo
                    model.fit(X_train, y_train, epochs=epochs, batch_size=32, verbose=0)

                    # Fazer previsões
                    y_pred = model.predict(X_test)

                    # Calcular o IoU médio
                    iou_medio = calcula_iou_medio(y_test, y_pred)
                    print(f"IoU médio: {iou_medio}")

                    # Atualizar os melhores parâmetros se necessário
                    if iou_medio > best_iou:
                        best_iou = iou_medio
                        best_params = (hidden_units, activation, learning_rate, epochs)

    print(f"Melhor IoU: {best_iou}")
    print(f"Melhores parâmetros: hidden_units={best_params[0]}, activation={best_params[1]}, learning_rate={best_params[2]}, epochs={best_params[3]}")

# Execução do código no ambiente Colab
set_seed()

# Definir os hiperparâmetros a serem testados
hidden_units_list = [
    (128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]  # Diferentes tamanhos de camadas ocultas
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]  # Diferentes taxas de aprendizado
epochs_list = [10, 20, 30, 40, 50]  # Diferentes números de épocas a serem testados

# Testar os modelos
test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list)

# %%
# Função para calcular o IoU
def calcula_iou(bbox_real, bbox_predito):
    xA = max(bbox_real[0], bbox_predito[0])
    yA = max(bbox_real[2], bbox_predito[2])
    xB = min(bbox_real[1], bbox_predito[1])
    yB = min(bbox_real[3], bbox_predito[3])

    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    boxA_area = (bbox_real[1] - bbox_real[0] + 1) * (bbox_real[3] - bbox_real[2] + 1)
    boxB_area = (bbox_predito[1] - bbox_predito[0] + 1) * (bbox_predito[3] - bbox_predito[2] + 1)

    iou = interArea / float(boxA_area + boxB_area - interArea)
    return iou

def calcula_iou_medio(y_true, y_pred):
    iou_sum = 0
    count = len(y_true)

    for i in range(count):
        iou_sum += calcula_iou(y_true[i], y_pred[i])

    return iou_sum / count

# Carregar o DataFrame gerado com as anotações das bounding boxes
annotations_df = pd.read_csv('/content/dados/annotations_bbox2D_filtered.csv')

# Ordenar pelo 'instance_token' e 'timestamp' para garantir que os dados estejam na ordem correta
annotations_df = annotations_df.sort_values(by=['instance_token', 'timestamp'])

# Shift para obter múltiplos bboxes anteriores e criar colunas de diferença
time_steps = 5  # Número de timestamps anteriores a serem usados como input
for i in range(1, time_steps + 1):
    annotations_df[f'prev_bbox_min_x_{i}'] = annotations_df.groupby('instance_token')['bbox_min_x'].shift(i)
    annotations_df[f'prev_bbox_max_x_{i}'] = annotations_df.groupby('instance_token')['bbox_max_x'].shift(i)
    annotations_df[f'prev_bbox_min_y_{i}'] = annotations_df.groupby('instance_token')['bbox_min_y'].shift(i)
    annotations_df[f'prev_bbox_max_y_{i}'] = annotations_df.groupby('instance_token')['bbox_max_y'].shift(i)

# Remove as linhas onde não temos dados suficientes dos timestamps anteriores
annotations_df = annotations_df.dropna(subset=[f'prev_bbox_min_x_{i}' for i in range(1, time_steps + 1)])

# Definir as features (inputs) e a variável alvo (outputs)
input_columns = [
    f'prev_bbox_min_x_{i}' for i in range(1, time_steps + 1)
] + [
    f'prev_bbox_max_x_{i}' for i in range(1, time_steps + 1)
] + [
    f'prev_bbox_min_y_{i}' for i in range(1, time_steps + 1)
] + [
    f'prev_bbox_max_y_{i}' for i in range(1, time_steps + 1)
]

X = annotations_df[input_columns]
y = annotations_df[['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]

# Converter para numpy arrays e ajustar a dimensão para o modelo RNN
X = X.values.reshape((X.shape[0], time_steps, 4))
y = y.values

# Dividir em treino e teste mantendo a ordem temporal
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Função que cria o modelo RNN
def create_rnn_model(input_shape, hidden_units, activation, learning_rate):
    # Definir o input da rede
    input_layer = Input(shape=input_shape)

    # Adicionar camadas LSTM
    x = input_layer
    for units in hidden_units:
        x = LSTM(units=units, activation=activation, return_sequences=True)(x)

    # Adicionar a última camada LSTM sem "return_sequences"
    x = LSTM(units=hidden_units[-1], activation=activation)(x)

    # Camada densa final
    output_layer = Dense(4, activation='linear')(x)

    # Criar o modelo
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Função para testar os modelos com diferentes hiperparâmetros
def test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list):
    best_iou = 0
    best_params = None

    for hidden_units in hidden_units_list:
        for activation in activations:
            for learning_rate in learning_rates:
                for epochs in epochs_list:
                    print(f"Testing model with hidden_units={hidden_units}, activation={activation}, learning_rate={learning_rate}, epochs={epochs}")

                    # Criar o modelo
                    model = create_rnn_model(X_train.shape[1:], hidden_units, activation, learning_rate)

                    # Treinar o modelo
                    model.fit(X_train, y_train, epochs=epochs, batch_size=32, verbose=0)

                    # Fazer previsões
                    y_pred = model.predict(X_test)

                    # Calcular o IoU médio
                    iou_medio = calcula_iou_medio(y_test, y_pred)
                    print(f"IoU médio: {iou_medio}")

                    # Atualizar os melhores parâmetros se necessário
                    if iou_medio > best_iou:
                        best_iou = iou_medio
                        best_params = (hidden_units, activation, learning_rate, epochs)

    print(f"Melhor IoU: {best_iou}")
    print(f"Melhores parâmetros: hidden_units={best_params[0]}, activation={best_params[1]}, learning_rate={best_params[2]}, epochs={best_params[3]}")

# Execução do código no ambiente Colab
set_seed()

# Definir os hiperparâmetros a serem testados
hidden_units_list = [
    (128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]  # Diferentes tamanhos de camadas ocultas
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]  # Diferentes taxas de aprendizado
epochs_list = [10, 20, 30, 40, 50]  # Diferentes números de épocas a serem testados

# Testar os modelos
test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list)

# %%
# Função para calcular o IoU
def calcula_iou(bbox_real, bbox_predito):
    xA = max(bbox_real[0], bbox_predito[0])
    yA = max(bbox_real[2], bbox_predito[2])
    xB = min(bbox_real[1], bbox_predito[1])
    yB = min(bbox_real[3], bbox_predito[3])

    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    boxA_area = (bbox_real[1] - bbox_real[0] + 1) * (bbox_real[3] - bbox_real[2] + 1)
    boxB_area = (bbox_predito[1] - bbox_predito[0] + 1) * (bbox_predito[3] - bbox_predito[2] + 1)

    iou = interArea / float(boxA_area + boxB_area - interArea)
    return iou

def calcula_iou_medio(y_true, y_pred):
    iou_sum = 0
    count = len(y_true)

    for i in range(count):
        iou_sum += calcula_iou(y_true[i], y_pred[i])

    return iou_sum / count

# Carregar o DataFrame gerado com as anotações das bounding boxes
annotations_df = pd.read_csv('/content/dados/annotations_bbox2D_filtered.csv')

# Ordenar pelo 'instance_token' e 'timestamp' para garantir que os dados estejam na ordem correta
annotations_df = annotations_df.sort_values(by=['instance_token', 'timestamp'])

# Função para criar e testar os cenários
def run_scenario(time_steps, output_steps):
    # Shift para obter múltiplos bboxes anteriores e criar colunas de diferença
    for i in range(1, time_steps + 1):
        annotations_df[f'prev_bbox_min_x_{i}'] = annotations_df.groupby('instance_token')['bbox_min_x'].shift(i)
        annotations_df[f'prev_bbox_max_x_{i}'] = annotations_df.groupby('instance_token')['bbox_max_x'].shift(i)
        annotations_df[f'prev_bbox_min_y_{i}'] = annotations_df.groupby('instance_token')['bbox_min_y'].shift(i)
        annotations_df[f'prev_bbox_max_y_{i}'] = annotations_df.groupby('instance_token')['bbox_max_y'].shift(i)

    # Remove as linhas onde não temos dados suficientes dos timestamps anteriores
    annotations_df_filtered = annotations_df.dropna(subset=[f'prev_bbox_min_x_{i}' for i in range(1, time_steps + 1)])

    # Definir as features (inputs) e a variável alvo (outputs)
    input_columns = [
        f'prev_bbox_min_x_{i}' for i in range(1, time_steps + 1)
    ] + [
        f'prev_bbox_max_x_{i}' for i in range(1, time_steps + 1)
    ] + [
        f'prev_bbox_min_y_{i}' for i in range(1, time_steps + 1)
    ] + [
        f'prev_bbox_max_y_{i}' for i in range(1, time_steps + 1)
    ]

    output_columns = ['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']
    for i in range(1, output_steps):
        annotations_df_filtered[f'future_bbox_min_x_{i}'] = annotations_df_filtered.groupby('instance_token')['bbox_min_x'].shift(-i)
        annotations_df_filtered[f'future_bbox_max_x_{i}'] = annotations_df_filtered.groupby('instance_token')['bbox_max_x'].shift(-i)
        annotations_df_filtered[f'future_bbox_min_y_{i}'] = annotations_df_filtered.groupby('instance_token')['bbox_min_y'].shift(-i)
        annotations_df_filtered[f'future_bbox_max_y_{i}'] = annotations_df_filtered.groupby('instance_token')['bbox_max_y'].shift(-i)
        output_columns += [f'future_bbox_min_x_{i}', f'future_bbox_max_x_{i}', f'future_bbox_min_y_{i}', f'future_bbox_max_y_{i}']

    # Remove as linhas onde não temos dados suficientes dos timestamps futuros
    annotations_df_filtered = annotations_df_filtered.dropna(subset=[f'future_bbox_min_x_{i}' for i in range(1, output_steps)])

    X = annotations_df_filtered[input_columns]
    y = annotations_df_filtered[output_columns]

    # Converter para numpy arrays e ajustar a dimensão para o modelo RNN
    X = X.values.reshape((X.shape[0], time_steps, 4))
    y = y.values.reshape((y.shape[0], output_steps, 4))

    # Dividir em treino e teste mantendo a ordem temporal
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Testar os modelos
    print(f"\nRodando cenário com {time_steps} inputs e {output_steps} outputs")
    test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list)

# Função que cria o modelo RNN
def create_rnn_model(input_shape, hidden_units, activation, learning_rate):
    # Definir o input da rede
    input_layer = Input(shape=input_shape)

    # Adicionar camadas LSTM
    x = input_layer
    for units in hidden_units:
        x = LSTM(units=units, activation=activation, return_sequences=True)(x)

    # Adicionar a última camada LSTM sem "return_sequences"
    x = LSTM(units=hidden_units[-1], activation=activation)(x)

    # Camada densa final
    output_layer = Dense(input_shape[0] * 4, activation='linear')(x)
    output_layer = tf.reshape(output_layer, (-1, input_shape[0], 4))

    # Criar o modelo
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Função para testar os modelos com diferentes hiperparâmetros
def test_rnn_models(X_train, X_test, y_train, y_test, hidden_units_list, activations, learning_rates, epochs_list):
    best_iou = 0
    best_params = None

    for hidden_units in hidden_units_list:
        for activation in activations:
            for learning_rate in learning_rates:
                for epochs in epochs_list:
                    print(f"Testing model with hidden_units={hidden_units}, activation={activation}, learning_rate={learning_rate}, epochs={epochs}")

                    # Criar o modelo
                    model = create_rnn_model(X_train.shape[1:], hidden_units, activation, learning_rate)

                    # Treinar o modelo
                    model.fit(X_train, y_train, epochs=epochs, batch_size=32, verbose=0)

                    # Fazer previsões
                    y_pred = model.predict(X_test)

                    # Calcular o IoU médio
                    iou_medio = calcula_iou_medio(y_test.reshape(-1, 4), y_pred.reshape(-1, 4))
                    print(f"IoU médio: {iou_medio}")

                    # Atualizar os melhores parâmetros se necessário
                    if iou_medio > best_iou:
                        best_iou = iou_medio
                        best_params = (hidden_units, activation, learning_rate, epochs)

    print(f"Melhor IoU: {best_iou}")
    print(f"Melhores parâmetros: hidden_units={best_params[0]}, activation={best_params[1]}, learning_rate={best_params[2]}, epochs={best_params[3]}")

# Execução do código no ambiente Colab
set_seed()

# Definir os hiperparâmetros a serem testados
hidden_units_list = [
    (128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]  # Diferentes tamanhos de camadas ocultas
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]  # Diferentes taxas de aprendizado
epochs_list = [10, 20, 30, 40, 50]  # Diferentes números de épocas a serem testados

# Executar os quatro cenários
run_scenario(5, 5)
run_scenario(10, 5)
run_scenario(5, 10)
run_scenario(10, 10)
run_scenario(5, 1)
run_scenario(10, 1)
run_scenario(15, 1)
