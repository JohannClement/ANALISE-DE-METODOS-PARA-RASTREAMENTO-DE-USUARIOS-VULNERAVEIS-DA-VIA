# %% [markdown]
# # Download das nuscenes mini

# %%
import os
import subprocess

def download(url, path):

    # comando para fazer o download
    cmd = ['wget', '-q', url, '-O', '%s' %(path)]

    # executa o comando sem exibir a saída na tela
    processo = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # aguarda o término do download
    stdout, stderr = processo.communicate()

    # Verifica se o processo foi concluído com sucesso (código de retorno zero)
    if processo.returncode == 0:
        print(f'Processo finalizado.')
    else:
        print(f'Houve um erro: {stderr.decode("utf-8")}')

# especifica o local onde ficarao os arquivos
pathFiles = 'dados/'

# cria uma pasta onde ficarao os arquivos
if not os.path.isdir(pathFiles):
    os.mkdir(pathFiles)

url = 'https://www.nuscenes.org/data/v1.0-mini.tgz'
pathDataset1 = pathFiles + '/nuscenes_v1.0-mini.tgz'
download(url, pathDataset1)
# Out:
# Processo finalizado.

# %% [markdown]
# Descompacta a base de dados.

# %%
import tarfile

def descompacta(path, pathFolder):

    try:
        # Descompacta ao arquivo
        with tarfile.open(pathDataset1, 'r:gz') as tar:
          tar.extractall(path=pathFolder)

        print("Arquivo descompactado com sucesso!")
    except:
        print("Houve um erro ao tentar descompactar o arquivo")

pathFiles = pathFiles + "/nuscenes"

# Cria o diretório de extração se não existir
os.makedirs(pathFiles, exist_ok=True)

descompacta(pathDataset1, pathFiles)
# Out:
# Arquivo descompactado com sucesso!

# %% [markdown]
# Instala a nuscenes

# %%
# !pip install nuscenes-devkit &> /dev/null  # Install nuScenes.

# %% [markdown]
# # Converte uma bounding box 3D para 2D
#
# A função abaixo recebe as informações da bounding box 3D de um determinado objeto e as informações de calibração da câmera. Com base nisso, ela faz a conversão para 2D. Esse código foi baseado no notebook disponível nesse link:
# - <https://github.com/asvath/mobile_robotics/blob/master/nuscenes%20extract%20and%20write%20out%202d%20annotation%20boxes-revised%20to%20truncate%20bb.ipynb>

# %%
import numpy as np
import pandas as pd
import cv2
from nuscenes.nuscenes import NuScenes

from pyquaternion import Quaternion

from nuscenes.utils.data_classes import Box
from nuscenes.utils.geometry_utils import view_points, BoxVisibility, box_in_image

import matplotlib.pyplot as plt

def threeD_2_twoD(boxsy,intrinsic): #input is a single annotation box
    '''
    given annotation boxes and intrinsic camera matrix
    outputs the 2d bounding box coordinates as a list (all annotations for a particular sample image)
    '''
    corners = boxsy.corners()
    x = corners[0,:]
    y = corners[1,:]
    z = corners[2,:]
    x_y_z = np.array((x,y,z))
    orthographic = np.dot(intrinsic,x_y_z)
    perspective_x = orthographic[0]/orthographic[2]
    perspective_y = orthographic[1]/orthographic[2]
    perspective_z = orthographic[2]/orthographic[2]

    min_x = int(np.min(perspective_x))
    max_x = int(np.max(perspective_x))
    min_y = int(np.min(perspective_y))
    max_y = int(np.max(perspective_y))

    return min_x,max_x,min_y,max_y

def getBoundBox(nusc, sample, camera, annotation_metadata):
    """
    Obtém a bounding box 3D e, depois, usando as informações da câmera,
    chama a função que converte para 2D
    """

    camera_token = sample['data'][camera]

    # Carregue os dados da câmera
    cam_data = nusc.get('sample_data', camera_token)

    cam_intrinsics = np.array(nusc.get('calibrated_sensor', cam_data['calibrated_sensor_token'])['camera_intrinsic'])
    cam_height = cam_data['height']
    cam_width = cam_data['width']

    # obtenha a bounding box 3D do pedestre
    # a variavel ann foi filtrada a partir do token do pedestre. Portanto, o parametro translation contem
    # as coordenadas do pedestre em questao
    translation = annotation_metadata['translation']
    size = annotation_metadata['size']
    rotation = Quaternion(annotation_metadata['rotation'])
    bbox = Box(translation, size, rotation)

    # Obtenha a pose da câmera
    ego_pose = nusc.get('ego_pose', cam_data['ego_pose_token'])
    cam_pose = nusc.get('calibrated_sensor', cam_data['calibrated_sensor_token'])

    # Transforme a bounding box do pedestre para o sistema de coordenadas da câmera
    bbox.translate(-np.array(ego_pose['translation']))
    bbox.rotate(Quaternion(ego_pose['rotation']).inverse)
    bbox.translate(-np.array(cam_pose['translation']))
    bbox.rotate(Quaternion(cam_pose['rotation']).inverse)

    # Verificar se a bounding box está dentro do campo de visão da câmera
    if not box_in_image(bbox, cam_intrinsics, imsize=[cam_width, cam_height], vis_level=BoxVisibility.ANY):
        return None, None, None, None

    # converts box into image plane
    min_x, max_x, min_y, max_y = threeD_2_twoD(bbox,cam_intrinsics)

    return min_x, max_x, min_y, max_y

# %% [markdown]
# A função abaixo aplica a conversão das bounding box para todas as anotações da base de dados. Além disso, guarda todas as informações em um dataframe.

# %%
def get_scenes(nusc):

    columns = ['scene_token', 'category_name', 'instance_token', 'translation', 'size', 'rotation']
    annotations_df = pd.DataFrame(columns=columns)

    dataList = []
    for scene in nusc.scene:
        scene_token = scene['token']
        print(f"Processing scene: {scene_token}")  # Adicione esta linha para depuração
        sample_token = scene['first_sample_token']

        while sample_token:
            sample = nusc.get('sample', sample_token)

            scene_token = sample['scene_token']
            timestamp = sample['timestamp']

            # coletar todos os caminhos das imagens da câmera
            for sensor_channel in ['CAM_FRONT', 'CAM_BACK', 'CAM_FRONT_LEFT', 'CAM_FRONT_RIGHT', 'CAM_BACK_LEFT', 'CAM_BACK_RIGHT']:
                sample_data_token_camera = sample['data'][sensor_channel]
                sample_data_camera = nusc.get('sample_data', sample_data_token_camera)
                image_path = sample_data_camera['filename']


                for annotation_token in sample['anns']:
                    annotation_metadata = nusc.get('sample_annotation', annotation_token)
                    instance_metadata = nusc.get('instance', annotation_metadata['instance_token'])
                    category_metadata = nusc.get('category', instance_metadata['category_token'])

                    # visibility_token = annotation_metadata['visibility_token']

                    # obter descrição da visibilidade
                    # visibility = nusc.get('visibility', visibility_token)['description']

                    min_x, max_x, min_y, max_y = getBoundBox(nusc, sample, sensor_channel, annotation_metadata)

                    data = {
                        'sample_token_camera': sample_data_token_camera,
                        'sample_token': sample_token,
                        'scene_token': scene_token,  # Certifique-se de que `scene_token` está sendo atribuído aqui
                        'instance_token': annotation_metadata['instance_token'],
                        'category_name': category_metadata['name'],
                        'image_path': image_path,
                        'camera': sensor_channel,
                        'translation': annotation_metadata['translation'],
                        'size': annotation_metadata['size'],
                        'rotation': annotation_metadata['rotation'],
                        'timestamp': timestamp,
                        # 'box_visibility': visibility_token,
                        'bbox_min_x': min_x,
                        'bbox_max_x': max_x,
                        'bbox_min_y': min_y,
                        'bbox_max_y': max_y,
                    }

                    dataList.append(data)

            sample_token = sample['next']

    # converta para um dataframe
    annotations_df = pd.DataFrame(dataList)

    # Ordenar pelo campo 'timestamp'
    annotations_df = annotations_df.sort_values(by='timestamp')

    annotations_df.to_csv('annotations_with_scenes.csv', index=False)

    return annotations_df

# %% [markdown]
# Converte toda a base de dados e salva como .csv

# %%
if __name__ == "__main__":

    pathDataset = "/content/dados/nuscenes/"

    path = "dados/annotations_bbox2D.csv"

    nusc = NuScenes(version='v1.0-mini', dataroot=pathDataset, verbose=True)

    annotations_df = get_scenes(nusc)

    annotations_df.to_csv(path, index=False)
# Out:
# ======
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 1.164 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.2 seconds.
# ======
# Processing scene: cc8c0bf57f984915a77078b10eb33198
# Processing scene: fcbccedd61424f1b85dcbf8f897f9754
# Processing scene: 6f83169d067343658251f72e1dd17dbc
# Processing scene: bebf5f5b2a674631ab5c88fd1aa9e87a
# Processing scene: 2fc3753772e241f2ab2cd16a784cc680
# Processing scene: c5224b9b454b4ded9b5d2d2634bbda8a
# Processing scene: 325cef682f064c55a255f2625c533b75
# Processing scene: d25718445d89453381c659b9c8734939
# Processing scene: de7d80a1f5fb4c3e82ce8a4f213b450a
# Processing scene: e233467e827140efa4b42d2b4c435855

# %% [markdown]
# # Filtra a base de dados
#
# A função abaixo filtra apenas algumas categorias de interesse.

# %%
def filtraCategorias(annotations_df):
    # Definir as categorias de interesse - apenas pedestres
    categories_of_interest = [
        'human.pedestrian.adult',
        'human.pedestrian.child',
        'human.pedestrian.construction_worker',
        'human.pedestrian.personal_mobility',
        'human.pedestrian.police_officer'
    ]

    # Filtrar as anotações que correspondem a essas categorias
    filtered_annotations_df = annotations_df[annotations_df['category_name'].isin(categories_of_interest)]

    return filtered_annotations_df

# %% [markdown]
# A função abaixo remove as bounding box nulas. Depois, aplica as duas funções.

# %%
def remove_bbox_nula(df):
    """
    Remove as linhas onde a bounding box é nula
    """

    df = df.dropna(subset=['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y'])

    return df

# %% [markdown]
# Aplica a função que seleciona algumas categorias e a função que remove as bounding box nulas.

# %%
if __name__ == "__main__":

  path_filtered = "dados/annotations_bbox2D_filtered.csv"

  # aplica a função que filtra as categorias desejadas
  annotations_df_filtered = filtraCategorias(annotations_df)

  # aplica a função que remove as bouding box nulas
  annotations_df_filtered = remove_bbox_nula(annotations_df_filtered)

  # salva o dataframe
  annotations_df_filtered.to_csv(path_filtered, index=False)

# %% [markdown]
# #Processamento de Dados e Função de Calculo de IoU

# %%
import pandas as pd

# Carrega o DataFrame gerado com as anotações das bounding boxes
annotations_df = pd.read_csv('/content/dados/annotations_bbox2D_filtered.csv')

# Ordenar pelo 'instance_token' e 'timestamp' para garantir que os dados estejam na ordem correta
annotations_df = annotations_df.sort_values(by=['instance_token', 'timestamp'])

# Shift para obter o bbox do timestamp anterior e criar colunas de diferença
annotations_df['prev_bbox_min_x'] = annotations_df.groupby('instance_token')['bbox_min_x'].shift(1)
annotations_df['prev_bbox_max_x'] = annotations_df.groupby('instance_token')['bbox_max_x'].shift(1)
annotations_df['prev_bbox_min_y'] = annotations_df.groupby('instance_token')['bbox_min_y'].shift(1)
annotations_df['prev_bbox_max_y'] = annotations_df.groupby('instance_token')['bbox_max_y'].shift(1)

# Remove as linhas onde não temos dados prévios
annotations_df = annotations_df.dropna(subset=['prev_bbox_min_x', 'prev_bbox_max_x', 'prev_bbox_min_y', 'prev_bbox_max_y'])

# Definir as features (inputs) e a variável alvo (outputs)
X = annotations_df[['prev_bbox_min_x', 'prev_bbox_max_x', 'prev_bbox_min_y', 'prev_bbox_max_y',
                    'bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]
y = annotations_df[['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]

# %%
def calcula_iou(bbox_real, bbox_predito):
    """
    Calcula o IoU (Intersection over Union) entre duas bounding boxes.
    """
    xA = max(bbox_real[0], bbox_predito[0])
    yA = max(bbox_real[2], bbox_predito[2])
    xB = min(bbox_real[1], bbox_predito[1])
    yB = min(bbox_real[3], bbox_predito[3])

    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    boxA_area = (bbox_real[1] - bbox_real[0] + 1) * (bbox_real[3] - bbox_real[2] + 1)
    boxB_area = (bbox_predito[1] - bbox_predito[0] + 1) * (bbox_predito[3] - bbox_predito[2] + 1)

    iou = interArea / float(boxA_area + boxB_area - interArea)
    return iou

def calcula_iou_medio(y_true, y_pred):
    """
    Calcula o IoU médio entre todos os pares de bounding boxes.
    """
    iou_sum = 0
    count = len(y_true)

    for i in range(count):
        iou_sum += calcula_iou(y_true[i], y_pred[i])

    return iou_sum / count

# %% [markdown]
# #Criação e Teste dos modelos

# %% [markdown]
# ##Modelo para prever a bounding box do próximo frame

# %%
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import tensorflow as tf
import random
import os

# Função para definir a seed global para reprodução dos resultados
def set_seed(seed_value=42):
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)

    # Configurações adicionais para reprodução consistente no TensorFlow
    os.environ['PYTHONHASHSEED'] = str(seed_value)  # Hash seed
    os.environ['TF_DETERMINISTIC_OPS'] = '1'  # Força operações determinísticas no TensorFlow

    # Configurações adicionais para TensorFlow
    # Definir configuração para limitar o uso de threads paralelos
    tf.config.threading.set_intra_op_parallelism_threads(1)
    tf.config.threading.set_inter_op_parallelism_threads(1)

# Chamar a função para definir a seed
set_seed()

# Definir os hiperparâmetros a serem testados
hidden_units = [
    (128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]  # Diferentes tamanhos de camadas ocultas
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]  # Diferentes taxas de aprendizado
epochs_list = [10, 20, 30, 40, 50]  # Diferentes números de épocas a serem testados

# Dividir em treino e teste mantendo a ordem temporal
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]



# Função para criar o modelo com hiperparâmetros variáveis
def create_model(hidden_units, activation, learning_rate):
    # Definir os inputs da rede (bbox no timestamp anterior e atual)
    input_prev = Input(shape=(4,), name='input_prev_bbox')
    input_current = Input(shape=(4,), name='input_current_bbox')

    # Definir o ramo siamesa compartilhado
    def siamese_branch(input_layer):
        x = input_layer
        for units in hidden_units:
            x = Dense(units, activation=activation)(x)
        return x

    # Aplicar o ramo siamesa para as duas entradas
    output_prev = siamese_branch(input_prev)
    output_current = siamese_branch(input_current)

    # Concatenar as saídas dos dois ramos
    merged = Concatenate()([output_prev, output_current])

    # Camada de saída para prever a bbox futura
    output = Dense(4, activation='linear')(merged)

    # Criar o modelo
    model = Model(inputs=[input_prev, input_current], outputs=output)

    # Compilar o modelo
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Armazenar os melhores resultados
best_model = None
best_iou = 0
best_hyperparams = {}

# Loop pelos hiperparâmetros
for hidden in hidden_units:
    for activation in activations:
        for lr in learning_rates:
            for epochs in epochs_list:
                print(f"Testando modelo com {hidden} camadas ocultas, ativação {activation}, lr {lr}, epochs {epochs}")

                # Criar o modelo com os hiperparâmetros atuais
                model = create_model(hidden, activation, lr)

                # Treinar o modelo
                model.fit([X_train[['prev_bbox_min_x', 'prev_bbox_max_x', 'prev_bbox_min_y', 'prev_bbox_max_y']],
                           X_train[['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]],
                          y_train, epochs=epochs, batch_size=32, verbose=0)

                # Fazer predições
                predictions = model.predict([X_test[['prev_bbox_min_x', 'prev_bbox_max_x', 'prev_bbox_min_y', 'prev_bbox_max_y']],
                                             X_test[['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']]])

                # Calcular o IoU médio
                iou_medio = calcula_iou_medio(y_test.values, predictions)
                print(f"IoU médio: {iou_medio}")

                # Verificar se este é o melhor modelo
                if iou_medio > best_iou:
                    best_iou = iou_medio
                    best_model = model
                    best_hyperparams = {
                        'hidden_units': hidden,
                        'activation': activation,
                        'learning_rate': lr,
                        'epochs': epochs
                    }

# Exibir os melhores hiperparâmetros
print(f"Melhor combinação de hiperparâmetros: {best_hyperparams}")
print(f"Melhor IoU médio: {best_iou}")
# Out:
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7568891821607336
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7933421115150642
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8285111300752686
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8699910158412525
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8640613593926028
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7971168069003554
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.8140326716835278
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.44617863241305206
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8821124338774026
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8035148949055397
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.3245724556852513
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.5457833891932476
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.38860889723489417
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7332052732773182
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6089012438770256
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.3841356056716511
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.36664105424986837
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5152062426786628
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7051009708627053
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6766229096726881
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5761187035162091
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6928630988979355
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6490645847520423
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7164448289207551
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7304730378658901
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5295036034247294
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5422126151617095
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7590935876318567
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# IoU médio: 0.5382328071251855
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7084946653311448
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.46334899307234606
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.661048318353287
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7714321990731563
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7350047049174866
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.790275230648081
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7263529806752467
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6178188846106807
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5125820233968859
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7546316325599567
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7980326212655972
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6014066073086299
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.6322345689079988
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.4350836067352856
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.4919494310276126
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6259338047062689
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.09831087765995476
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6719482412940636
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6610511108314638
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.4047417495566609
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8029228323806644
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5651884264699514
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8326952094813219
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7326020308023888
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7594606426226899
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7181911418252857
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6097879111786562
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5406588476346659
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.45517212807777013
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5227678010699862
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5778981661386821
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.3826410774938772
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.41639256943750097
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.6583344679779098
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.3912785170747065
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.8443467987234442
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7131461397298983
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# IoU médio: 0.5566314242339835
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.725179091892809
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.6710772302028111
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7467232179084223
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.6723496375706952
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.4957623052450086
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.582959683761884
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.5602568513244437
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.5940951564286777
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.5144232363644727
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.4710775675637305
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.6596057553562512
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.4783277541671737
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6489203924264345
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.743382728373653
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.8006632442492748
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.848368837313783
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5625332312982942
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.9100107450244209
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5774603393207286
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.37860911743295944
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6950849939436736
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8237046101584543
# Testando modelo com (128, 64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6000105083221827
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5713921007084682
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7410982077767043
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8405970555369794
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7919275321104254
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8331005114583294
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8246110812748488
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8642754170859364
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.858338541876268
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7674734757523594
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.9426619516823207
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8633466625415838
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.49082297445930256
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.08393164249859285
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6688959281220047
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.9329724529748569
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.16845065632294998
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.4470879634928459
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6094096370232108
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7704592191851831
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6213012746661976
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7340980999028818
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.37547568094930994
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7447615615353191
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8312558002560292
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8708074224753074
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5770952984945538
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.4194220821700579
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6449596547839501
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.87086808225404
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5407920050519146
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.27306335968681533
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5889343165673774
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6731021829941877
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7415881956360798
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7738936868285171
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6381545845839682
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7880876753054439
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7317991490725636
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8296184822688051
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7568404599739162
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5300010477547751
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6567362810138375
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6549366611544427
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7448607256303456
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7335224228608325
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.3657405879077241
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.3797294655538751
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6037983609416774
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7551359029183531
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5192903397529309
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6771683634694415
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7264348187542369
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7192637765465775
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7898193775165079
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8547571055157488
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# IoU médio: 0.7317969074851943
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7745801311442612
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.711103831376727
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.6553635010365583
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8306167942900748
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# IoU médio: 0.3382753534182976
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# IoU médio: 0.04605450042385211
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# IoU médio: 0.29276751378434096
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.5629179218531464
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7734972498034307
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# IoU médio: 0.7022251701532106
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.7066349379815049
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.8007618515901546
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8357076641776259
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.8506605105377484
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.39075089839527394
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# IoU médio: 0.31759515627499135
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.367400101746758
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.5013378204535177
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# IoU médio: 0.60646142613567
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.24445472213127195
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5631665485560905
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.5901837402275015
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7119175855835841
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.3691025038331818
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.4835235876244811
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6215507543924601
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8228652988219032
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6878035909135138
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7887437794608976
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6470239671159564
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.3251661992772339
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7821164332701159
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8735859027327196
# Testando modelo com (64, 32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.858746417835075
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.11148104783744378
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5516691594689745
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6448616165544231
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7571184078764591
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7725020462401251
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7319555338133291
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8330527391460556
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.922451189440924
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8736878674788723
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8302335150638009
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7842627739732547
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7153509106582951
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.372657314106533
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.9091433073472336
# Testando modelo com (32, 16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5134441837406235
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.014651105282207883
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.46948882453304897
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7046487729730107
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6785485249688662
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7039936083352627
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6735572320130672
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6840755200719503
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7517008711871784
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8263099750835161
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8984846792366982
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6907772409106641
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7329471919795911
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7698175251639066
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7532697116344169
# Testando modelo com (32, 16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7727087025276499
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.07470718126443608
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.3158714199864102
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.31307495114182704
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6031582345017241
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.582825499924061
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.659546162519562
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.740362804394637
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7846706386157908
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8687407856676433
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8612436828185489
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7620526956728755
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5212234179212832
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.732523907359197
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6522050750316483
# Testando modelo com (32, 16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7888567862890649
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.0781843146450238
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.44451301492506523
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5266218872034745
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5022709760706999
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6335044003961998
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.46332960357876
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7111824442077858
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.831381569813796
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.709071325113734
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7860976284561532
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.604836064525744
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6354768868508309
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6725932364755157
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8883369039354694
# Testando modelo com (32, 16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6999749391471213
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.19100740771181512
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.4198831528615766
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.43436525046304775
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6716885191190717
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.5184228269492974
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7657105867539007
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7085492074210499
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7901274309218913
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8108629818926677
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.9013463727521942
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.18776533432783624
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.24907630670999378
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6915835577232771
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.724930026979989
# Testando modelo com (32, 16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.8400799964412649
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.11239415696284034
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.3846137803510449
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.3505810170709083
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.48306923244916916
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.6461921997419228
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6502415645734587
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7721865414041423
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7890578871255638
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7899895479033961
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8597412262336376
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7060593450512144
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7146946100943739
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.4517882566854784
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8122124020949735
# Testando modelo com (32, 16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8113164826427074
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.14523311986843154
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.19617384185235176
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.41128755023828745
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5828112560473621
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7931952633673856
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7370244291698765
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7411043512820242
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7404137381905027
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8685122789522122
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.9097963532744716
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8437793054326499
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8234385569086907
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7280775724884762
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.6136352049506565
# Testando modelo com (16, 8) camadas ocultas, ativação linear, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.71040635199269
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.05967322157903789
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.05623706490683661
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.28140849569687193
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.4710622708069403
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.38924568267367515
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.508113584748564
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.607163383209649
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6727840969536565
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7209785899269634
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7733911457661952
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8012024663786323
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.7731331522807839
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8109131678489054
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8025667690165665
# Testando modelo com (16, 8) camadas ocultas, ativação relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8109912526693979
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.04486225577976666
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.1813308035688497
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.2028915475231274
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.41551920533597997
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.5014824673057137
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6224163697555761
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6663957795500882
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7125347963441828
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8006291005533828
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8804950919765983
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.8249955760954608
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8639744135611984
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.711363223288274
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.41272317618867904
# Testando modelo com (16, 8) camadas ocultas, ativação leaky_relu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7048052341315892
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.04781829066979297
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.08107973539928247
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.34061280031906155
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.48639140819679305
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5679678579178712
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6168797290550889
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7745061915473239
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8132702801203048
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8098793953286774
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.6501727458949453
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6311333863517645
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.8647686241751216
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7463549612273839
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5403054296668357
# Testando modelo com (16, 8) camadas ocultas, ativação selu, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.9225705879335719
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.020461226633882845
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.08136616195113452
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.332265858877139
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.4052108736415401
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.4084169030426861
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5282187760499242
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.6597111520132956
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.3763009570559537
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6337340695142603
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8636552773755066
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.8276076254488036
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7319848730659172
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7327442219077617
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6838661402760412
# Testando modelo com (16, 8) camadas ocultas, ativação swish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.7204393493743233
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.03522919284388993
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.13592760755316174
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.2333843382069115
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.12108694679163927
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.3982440912800843
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# IoU médio: 0.35081206605533555
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.4852644609450488
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7910578492800527
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7302145239503086
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7734745299341701
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7080303823062796
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7505684729357748
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6925266381412502
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.5398391714486087
# Testando modelo com (16, 8) camadas ocultas, ativação mish, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7151638406598051
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.783197103260497
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# IoU médio: 0.7584575232116987
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8090274445421902
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8350664533671196
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.0001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.8581803023080565
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8246938193016734
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.889978237641157
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7852007200822021
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8707151419342948
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.001, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.8447005844464153
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.01, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.6837584002806737
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.01, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.40389171773130444
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.01, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6729092996720181
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.01, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.9417268657555773
# Testando modelo com (64, 64) camadas ocultas, ativação linear, lr 0.01, epochs 50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.4470772214429188
# Testando modelo com (64, 64) camadas ocultas, ativação relu, lr 0.0001, epochs 10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# IoU médio: 0.5352910181338679
# Testando modelo com (64, 64) camadas ocultas, ativação relu, lr 0.0001, epochs 20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7078380368276781
# Testando modelo com (64, 64) camadas ocultas, ativação relu, lr 0.0001, epochs 30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.6949094261314935
# Testando modelo com (64, 64) camadas ocultas, ativação relu, lr 0.0001, epochs 40
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# IoU médio: 0.7479235069863853
# Testando modelo com (64, 64) camadas ocultas, ativação relu, lr 0.0001, epochs 50

# %% [markdown]
# ##Modelos para prever a bounding box:
# - Dos próximos 5 frames, com um histórico de 5 frames como input.</br>
# - Dos próximos 5 frames, com um histórico de 10 frames como input.</br>
# - Dos próximos 10 frames, com um histórico de 5 frames como input.</br>
# - Dos próximos 10 frames, com um histórico de 10 frames como input.</br>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.optimizers import Adam

# Funções reutilizadas de seu código anterior:
def calcula_iou(bbox_real, bbox_predito):
    # Função para calcular IoU
    xA = max(bbox_real[0], bbox_predito[0])
    yA = max(bbox_real[2], bbox_predito[2])
    xB = min(bbox_real[1], bbox_predito[1])
    yB = min(bbox_real[3], bbox_predito[3])

    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    boxA_area = (bbox_real[1] - bbox_real[0] + 1) * (bbox_real[3] - bbox_real[2] + 1)
    boxB_area = (bbox_predito[1] - bbox_predito[0] + 1) * (bbox_predito[3] - bbox_predito[2] + 1)

    iou = interArea / float(boxA_area + boxB_area - interArea)
    return iou

def calcula_iou_medio(y_true, y_pred):
    iou_sum = 0
    count = len(y_true)

    for i in range(count):
        iou_sum += calcula_iou(y_true[i], y_pred[i])

    return iou_sum / count

def create_model(input_shape, output_shape, hidden_units, activation, learning_rate):
    input_prev = Input(shape=input_shape, name='input_prev_bbox')

    # Definir o ramo siamesa compartilhado
    def siamese_branch(input_layer):
        x = input_layer
        for units in hidden_units:
            x = Dense(units, activation=activation)(x)
        return x

    # Aplicar o ramo siamesa para as entradas
    output_prev = siamese_branch(input_prev)

    # Camada de saída para prever a bbox futura
    output = Dense(output_shape[0], activation='linear')(output_prev)

    # Criar o modelo
    model = Model(inputs=[input_prev], outputs=output)

    # Compilar o modelo
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Função para formatar os dados de acordo com o número de frames de input/output
def format_data(annotations_df, num_input_frames, num_output_frames):
    X = []
    y = []

    # Garantir que os dados sejam ordenados por scene_token, instance_token e timestamp
    annotations_df = annotations_df.sort_values(by=['scene_token', 'instance_token', 'timestamp'])

    # Criar as sequências de input/output para cada VRU dentro de uma cena
    grouped = annotations_df.groupby(['scene_token', 'instance_token'])

    for _, group in grouped:
        # Processar cada grupo (cada combinação de scene_token e instance_token)
        group = group.reset_index(drop=True)

        # Criar sequências respeitando o número de input e output frames
        for i in range(num_input_frames, len(group) - num_output_frames):
            X.append(group.iloc[i-num_input_frames:i][['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']].values.flatten())
            y.append(group.iloc[i:i+num_output_frames][['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']].values.flatten())

    return np.array(X), np.array(y)

# Configurações dos quatro cenários
scenarios = [
    {'input_frames': 5, 'output_frames': 5},
    {'input_frames': 5, 'output_frames': 10},
    {'input_frames': 10, 'output_frames': 5},
    {'input_frames': 10, 'output_frames': 10}
]

# Hiperparâmetros para testar
hidden_units = [(128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]
epochs_list = [10, 20, 30, 40, 50]

# Variáveis para armazenar os melhores resultados por cenário
best_models_per_scenario = {}

# Loop pelos cenários
for scenario in scenarios:
    print(f"Testando cenário: {scenario['input_frames']} input, {scenario['output_frames']} output")

    # Formatando os dados para este cenário
    X, y = format_data(annotations_df, scenario['input_frames'], scenario['output_frames'])

    # Dividir em treino e teste mantendo a ordem temporal
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Variáveis para armazenar o melhor resultado deste cenário
    best_model = None
    best_iou = 0
    best_hyperparams = {}

    # Loop pelos hiperparâmetros
    for hidden in hidden_units:
        for activation in activations:
            for lr in learning_rates:
                for epochs in epochs_list:
                    print(f"Testando modelo com {hidden} camadas ocultas, ativação {activation}, lr {lr}, epochs {epochs}")

                    # Criar o modelo com os hiperparâmetros atuais
                    model = create_model(X_train.shape[1:], y_train.shape[1:], hidden, activation, lr)

                    # Treinar o modelo
                    model.fit(X_train, y_train, epochs=epochs, batch_size=32, verbose=0)

                    # Fazer predições
                    predictions = model.predict(X_test)

                    # Calcular o IoU médio
                    iou_medio = calcula_iou_medio(y_test, predictions)
                    print(f"IoU médio: {iou_medio}")

                    # Verificar se este é o melhor modelo para o cenário atual
                    if iou_medio > best_iou:
                        best_iou = iou_medio
                        best_model = model
                        best_hyperparams = {
                            'hidden_units': hidden,
                            'activation': activation,
                            'learning_rate': lr,
                            'epochs': epochs
                        }

    # Armazenar o melhor modelo e hiperparâmetros para este cenário
    best_models_per_scenario[scenario['input_frames'], scenario['output_frames']] = {
        'best_model': best_model,
        'best_iou': best_iou,
        'best_hyperparams': best_hyperparams
    }

# Exibir os melhores hiperparâmetros e cenários
for scenario_key, best_model_data in best_models_per_scenario.items():
    print(f"Melhor cenário: Input Frames: {scenario_key[0]}, Output Frames: {scenario_key[1]}")
    print(f"Melhor combinação de hiperparâmetros: {best_model_data['best_hyperparams']}")
    print(f"Melhor IoU médio: {best_model_data['best_iou']}")

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.optimizers import Adam

# Funções reutilizadas de seu código anterior:
def calcula_iou(bbox_real, bbox_predito):
    # Função para calcular IoU
    xA = max(bbox_real[0], bbox_predito[0])
    yA = max(bbox_real[2], bbox_predito[2])
    xB = min(bbox_real[1], bbox_predito[1])
    yB = min(bbox_real[3], bbox_predito[3])

    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    boxA_area = (bbox_real[1] - bbox_real[0] + 1) * (bbox_real[3] - bbox_real[2] + 1)
    boxB_area = (bbox_predito[1] - bbox_predito[0] + 1) * (bbox_predito[3] - bbox_predito[2] + 1)

    iou = interArea / float(boxA_area + boxB_area - interArea)
    return iou

def calcula_iou_medio(y_true, y_pred):
    iou_sum = 0
    count = len(y_true)

    for i in range(count):
        iou_sum += calcula_iou(y_true[i], y_pred[i])

    return iou_sum / count

def create_model(input_shape, output_shape, hidden_units, activation, learning_rate):
    input_prev = Input(shape=input_shape, name='input_prev_bbox')

    # Definir o ramo siamesa compartilhado
    def siamese_branch(input_layer):
        x = input_layer
        for units in hidden_units:
            x = Dense(units, activation=activation)(x)
        return x

    # Aplicar o ramo siamesa para as entradas
    output_prev = siamese_branch(input_prev)

    # Camada de saída para prever a bbox futura
    output = Dense(output_shape[0], activation='linear')(output_prev)

    # Criar o modelo
    model = Model(inputs=[input_prev], outputs=output)

    # Compilar o modelo
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    return model

# Função para formatar os dados de acordo com o número de frames de input/output
def format_data(annotations_df, num_input_frames, num_output_frames):
    X = []
    y = []

    # Garantir que os dados sejam ordenados por scene_token, instance_token e timestamp
    annotations_df = annotations_df.sort_values(by=['scene_token', 'instance_token', 'timestamp'])

    # Criar as sequências de input/output para cada VRU dentro de uma cena
    grouped = annotations_df.groupby(['scene_token', 'instance_token'])

    for _, group in grouped:
        # Processar cada grupo (cada combinação de scene_token e instance_token)
        group = group.reset_index(drop=True)

        # Criar sequências respeitando o número de input e output frames
        for i in range(num_input_frames, len(group) - num_output_frames):
            X.append(group.iloc[i-num_input_frames:i][['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']].values.flatten())
            y.append(group.iloc[i:i+num_output_frames][['bbox_min_x', 'bbox_max_x', 'bbox_min_y', 'bbox_max_y']].values.flatten())

    return np.array(X), np.array(y)

# Configurações dos quatro cenários
scenarios = [
    {'input_frames': 5, 'output_frames': 1},
    {'input_frames': 10, 'output_frames': 1},
    {'input_frames': 15, 'output_frames': 1}
]

# Hiperparâmetros para testar
hidden_units = [(128, 64, 32, 16, 8), (64, 32, 16, 8), (32, 16, 8), (16, 8), (64, 64), (64, 32), (32, 32)]
activations = ['linear', 'relu', 'leaky_relu', 'selu', 'swish', 'mish']  # Funções de ativação
learning_rates = [0.0001, 0.001, 0.01]
epochs_list = [10, 20, 30, 40, 50]

# Variáveis para armazenar os melhores resultados por cenário
best_models_per_scenario = {}

# Loop pelos cenários
for scenario in scenarios:
    print(f"Testando cenário: {scenario['input_frames']} input, {scenario['output_frames']} output")

    # Formatando os dados para este cenário
    X, y = format_data(annotations_df, scenario['input_frames'], scenario['output_frames'])

    # Dividir em treino e teste mantendo a ordem temporal
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Variáveis para armazenar o melhor resultado deste cenário
    best_model = None
    best_iou = 0
    best_hyperparams = {}

    # Loop pelos hiperparâmetros
    for hidden in hidden_units:
        for activation in activations:
            for lr in learning_rates:
                for epochs in epochs_list:
                    print(f"Testando modelo com {hidden} camadas ocultas, ativação {activation}, lr {lr}, epochs {epochs}")

                    # Criar o modelo com os hiperparâmetros atuais
                    model = create_model(X_train.shape[1:], y_train.shape[1:], hidden, activation, lr)

                    # Treinar o modelo
                    model.fit(X_train, y_train, epochs=epochs, batch_size=32, verbose=0)

                    # Fazer predições
                    predictions = model.predict(X_test)

                    # Calcular o IoU médio
                    iou_medio = calcula_iou_medio(y_test, predictions)
                    print(f"IoU médio: {iou_medio}")

                    # Verificar se este é o melhor modelo para o cenário atual
                    if iou_medio > best_iou:
                        best_iou = iou_medio
                        best_model = model
                        best_hyperparams = {
                            'hidden_units': hidden,
                            'activation': activation,
                            'learning_rate': lr,
                            'epochs': epochs
                        }

    # Armazenar o melhor modelo e hiperparâmetros para este cenário
    best_models_per_scenario[scenario['input_frames'], scenario['output_frames']] = {
        'best_model': best_model,
        'best_iou': best_iou,
        'best_hyperparams': best_hyperparams
    }

# Exibir os melhores hiperparâmetros e cenários
for scenario_key, best_model_data in best_models_per_scenario.items():
    print(f"Melhor cenário: Input Frames: {scenario_key[0]}, Output Frames: {scenario_key[1]}")
    print(f"Melhor combinação de hiperparâmetros: {best_model_data['best_hyperparams']}")
    print(f"Melhor IoU médio: {best_model_data['best_iou']}")
